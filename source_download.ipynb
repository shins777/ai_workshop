# %% [markdown]
# ## 소스 다운로드

# %% [markdown]
# ### 구글 드라이브 연결

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ### 다운로드 위치 설정

# %%
cd "/content/drive/MyDrive"
# Out:
# /content/drive/MyDrive

# %% [markdown]
# ### git clone 을 통한 소스 다운로드

# %%
# !git clone https://github.com/shins777/ai_workshop.git
# Out:
# Cloning into 'ai_workshop'...
# remote: Enumerating objects: 87, done.
# remote: Counting objects: 100% (87/87), done.
# remote: Compressing objects: 100% (49/49), done.
# remote: Total 87 (delta 32), reused 87 (delta 32), pack-reused 0 (from 0)
# Receiving objects: 100% (87/87), 108.71 KiB | 4.18 MiB/s, done.
# Resolving deltas: 100% (32/32), done.
